# %% [markdown]
# # 07 — Full Model Comparison
#
# Part 8: every model evaluated together — common metrics, a unified forecast plot, error diagnostics, and explicit comparison against the strongest benchmark.

# %%
import sys
sys.path.insert(0, '../src')
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 120)
from IPython.display import Image, display

# %% [markdown]
# ## Full comparison, vs. strongest benchmark

# %%
comparison = pd.read_csv('../outputs/metrics/vs_strongest_benchmark.csv')
comparison
# Out:
#                    model        MAE        RMSE      MASE       Bias  pct_MAE_vs_strongest_benchmark  \
# 0                sarimax  38.055428   65.734392  0.943346  -4.972041                            12.4
# 1       foundation_model  38.679152   78.284746  0.958807 -33.682453                            11.0
# 2           sarimax_exog  39.687362   65.778199  0.983800   1.458044                             8.7
# 3          feature_model  42.536922   66.873291  1.054437   0.843181                             2.1
# 4  seasonal_naive_weekly  43.457341   81.408880  1.077253 -13.159722                             0.0
# 5   seasonal_naive_daily  48.308532   85.564719  1.197508   1.750992                           -11.2
# 6                   mean  50.258092   74.938304  1.245835  -3.286762                           -15.6
# 7                  naive  85.550595  110.389709  2.120691  50.977183                           -96.9
# ...

# %% [markdown]
# All four advanced models (SARIMAX, Chronos, SARIMAX+exog, XGBoost) beat the strongest benchmark; none of the five benchmarks do.

# %% [markdown]
# ## All models, one plot

# %%
display(Image(filename='../outputs/figures/all_models_forecast_comparison.png'))

# %% [markdown]
# ## Error diagnostics

# %%
display(Image(filename='../outputs/figures/error_diagnostics.png'))

# %% [markdown]
# Full discussion, the 6 required questions, limitations, and the final recommendation are in `reports/report.docx` / `report.pdf`.
