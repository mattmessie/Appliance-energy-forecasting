# %% [markdown]
# # 06 — Foundation Model (Chronos)
#
# Part 7: Chronos (`amazon/chronos-t5-tiny`), used zero-shot and target-only. **Note:** this model needs to download pretrained weights from Hugging Face Hub, which requires outbound internet access — see `scripts/run_chronos.py` for the actual fitting/forecasting code. This notebook displays the already-computed results.

# %%
import sys
sys.path.insert(0, '../src')
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 120)
from IPython.display import Image, display

# %% [markdown]
# ## Rolling forecast with 90% interval

# %%
display(Image(filename='../outputs/figures/foundation_model_forecast.png'))

# %% [markdown]
# Chronos tracks the routine daily cycle well despite zero exposure to this household's data, but systematically under-predicts large spikes, with intervals too narrow to contain them.

# %% [markdown]
# ## Results

# %%
comparison = pd.read_csv('../outputs/metrics/model_comparison.csv')
comparison[comparison['model'].isin(['foundation_model', 'sarimax', 'seasonal_naive_weekly'])]
# Out:
#                    model        MAE       RMSE      MASE       Bias
# 0                sarimax  38.055428  65.734392  0.943346  -4.972041
# 1       foundation_model  38.679152  78.284746  0.958807 -33.682453
# 4  seasonal_naive_weekly  43.457341  81.408880  1.077253 -13.159722
